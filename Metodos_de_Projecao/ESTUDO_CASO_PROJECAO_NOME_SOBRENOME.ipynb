# %% [markdown]
# # **ESTUDO DE CASO: MÉTODOS DE PROJEÇÃO**
# ##### **Nome do(a) Aluno(a)**: SEU NOME COMPLETO AQUI
# ##### **Case**: *Potencial de Novos Clientes* <br> **Base de Dados**: *Potencial_Novos_Clientes.txt*
# --------------

# %% [markdown]
# ### **INSTALAÇÃO/CARREGAMENTO DE BIBLIOTECAS**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# ### **LEITURA DA BASE DE DADOS**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# ### **QUESTÃO 1**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 2**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 3**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 4**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 5**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 6**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 7**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 8**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 9**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui

# %% [markdown]
# ### **QUESTÃO 10**

# %%
# Insira seus códigos em Python aqui (divida em várias células, se desejar)

# %% [markdown]
# Insira seu texto de conclusões aqui
